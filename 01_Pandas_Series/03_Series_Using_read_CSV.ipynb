# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Series Using Read CSV

# %%
subs = pd.read_csv('C:\\Users\\Malik Gee\\Desktop\\Pandas For DataScience\\Pandas_Series\\Data_Sets\\subs.csv')
subs.squeeze(True)
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
vk = pd.read_csv('C:\\Users\\Malik Gee\\Desktop\\Pandas For DataScience\\Pandas_Series\\Data_Sets\\kohli_ipl.csv',index_col='match_no')
vk.squeeze(True)
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('C:\\Users\\Malik Gee\\Desktop\\Pandas For DataScience\\Pandas_Series\\Data_Sets\\bollywood.csv')
movies.squeeze(True)
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]
