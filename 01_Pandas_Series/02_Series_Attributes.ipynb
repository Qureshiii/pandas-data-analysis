# %%
import numpy as np
import pandas as pd

marks = [67,57,89,100]
subjects =['maths','English','Science','Urdu']
marks_series = pd.Series(marks,index=subjects,name='Muttahir k Marks')

# %% [markdown]
# Series Attributes

# %%
# Size
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'Muttahir k Marks'

# %%
# is_Unique
marks_series.is_unique
# Out:
# True

# %%
# index 
marks_series.index
# Out:
# Index(['maths', 'English', 'Science', 'Urdu'], dtype='object')

# %%
# Values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])
