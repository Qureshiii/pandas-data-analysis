# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# Importing DataSets

# %%
df = pd.read_csv('C:\\Users\\Malik Gee\\Desktop\\Pandas For DataScience\\02_Pandas_DataFrame\\datasets-session-22\\expense_data.csv')

# %% [markdown]
# Creating TimeStamp Object

# %%
# different variations of timestamp object
pd.Timestamp('2026/8/5')
pd.Timestamp('2026, 8, 5')
pd.Timestamp('2026')
# with text
pd.Timestamp('5th Aug 2026')
# providing time 
pd.Timestamp('5th Aug 2026 4:12pm')
# other ways 
pd.Timestamp(2026, 8, 5, 16, 22)
# or 
pd.Timestamp('2026/8/5 4:18PM')
# or 
pd.Timestamp('2026-8-5 4:20:00PM')

# %% [markdown]
# Using DateTime Object in python

# %%
dt.datetime(2026,8,5,4,25)
x = pd.Timestamp(dt.datetime(2026,8,5,4,25,55))

# %%
x.year
x.month
x.day
x.hour
x.minute
x.second

# %% [markdown]
# Using Numpy

# %%
date = np.array('2015-07-04',dtype=np.datetime64)
date + np.arange(12)

# %% [markdown]
# Using DateTime Index

# %%
pd.DatetimeIndex(['2026/1/1','2025/1/1','2024/1/1'])[0]

# %% [markdown]
# Using python datetime object

# %%
pd.DatetimeIndex([dt.datetime(2026,1,1),dt.datetime(2025,1,1),dt.datetime(2024,1,1)])

# %% [markdown]
# Using pd.timestamp

# %%
dt_index = pd.DatetimeIndex([pd.Timestamp(2026,1,1),pd.Timestamp(2025,1,1),pd.Timestamp(2024,1,1)])

# %% [markdown]
# Using datetime index as series index

# %%
pd.Series([1,2,3],index=dt_index)

# %% [markdown]
#             Date range function

# %% [markdown]
# Generate Daily Dates in a given range.

# %%
pd.date_range(start='2026/08/07',end='2026/09/07')

# %% [markdown]
# alternate days in a given range

# %%
pd.date_range(start='2026/08/07',end='2026/09/07',freq='2D')

# %% [markdown]
# want only buissness days

# %%
pd.date_range(start='2026/08/07',end='2026/09/07',freq='B')

# %% [markdown]
# one day per week

# %%
pd.date_range(start='2026/08/07',end='2026/09/07',freq='W-FRI')

# %% [markdown]
# Want hourly timestamps

# %%
pd.date_range(start='2026/08/07',end='2026/09/07',freq='6h')

# %% [markdown]
# Month End

# %%
pd.date_range(start='2026/08/07',end='2026/09/07',freq='ME')

# %% [markdown]
# Month Start

# %%
pd.date_range(start='2026/08/07',end='2026/09/07',freq='MS')

# %% [markdown]
# Year End

# %%
pd.date_range(start='2026/08/07',end='2026/09/07',freq='YE')

# %% [markdown]
# Year Start

# %%
pd.date_range(start='2026/08/07',end='2026/09/07',freq='YS')

# %% [markdown]
# Using Periods

# %%
pd.date_range(start='2026/08/07',periods=25,freq='D')

# %% [markdown]
#             to datetime Function

# %% [markdown]
# Converts an existing objects to pandas timeStamp/datetime index object.

# %%
# Simple example 
s = pd.Series(['2026/1/1','2025/2/1','2024/3/1'])
pd.to_datetime(s).dt.day_name()

# %%
# with errors 
s = pd.Series(['2026/1/1','2025/2/1','2024/130/1'])
pd.to_datetime(s,errors='coerce')

# %% [markdown]
#             Working with DataFrame

# %%
# convert String Date to datetime
df['Date'] = pd.to_datetime(df['Date'])
df['Date'].dt.day_name()

# %% [markdown]
# Plot graph

# %%
plt.plot(df['Date'],df['INR'])

# %% [markdown]
# day name wise bar chart

# %%
df['day_name'] = df['Date'].dt.day_name()
df.groupby('day_name')['INR'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='day_name'>

# %% [markdown]
# month wise bar chart

# %%
df['month_name'] = df['Date'].dt.month_name()
df.groupby('month_name')['INR'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='month_name'>

# %%
df[df['Date'].dt.is_month_end]
# Out:
#                    Date               Account        Category  Subcategory  \
# 7   2022-02-28 11:56:00  CUB - online payment            Food          NaN
# 8   2022-02-28 11:45:00  CUB - online payment           Other          NaN
# 61  2022-01-31 08:44:00  CUB - online payment  Transportation          NaN
# 62  2022-01-31 08:27:00  CUB - online payment           Other          NaN
# 63  2022-01-31 08:26:00  CUB - online payment  Transportation          NaN
# 242 2021-11-30 14:24:00  CUB - online payment            Gift          NaN
# 243 2021-11-30 14:17:00  CUB - online payment            Food          NaN
# 244 2021-11-30 10:11:00  CUB - online payment            Food          NaN
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# 7                 Pizza  339.15        Expense     NaN  339.15      INR
# 8           From kumara  200.00         Income     NaN  200.00      INR
# 61           Vnr to apk   50.00        Expense     NaN   50.00      INR
# ...
